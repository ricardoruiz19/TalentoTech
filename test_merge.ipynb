# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardoruiz19/TalentoTech/blob/main/test_merge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)

# %%
df2 = pd.DataFrame(
       {
           "A": ["A4", "A5", "A6", "A7"],
           "B": ["B4", "B5", "B6", "B7"],
           "C": ["C4", "C5", "C6", "C7"],
           "D": ["D4", "D5", "D6", "D7"],
       },
       index=[4, 5, 6, 7],
   )

# %%
df3 = pd.DataFrame(
       {
           "A": ["A8", "A9", "A10", "A11"],
           "B": ["B8", "B9", "B10", "B11"],
           "C": ["C8", "C9", "C10", "C11"],
           "D": ["D8", "D9", "D10", "D11"],
       },
       index=[8, 9, 10, 11],
   )

# %%
frames = [df1, df2, df3]

result = pd.concat(frames)

# %%
display(result)
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
import pandas as pd

# File paths
file1_path = r"/content/importaciones_1.xlsx"
file2_path = r"/content/importaciones_2.xlsx"

# Read the Excel files
df1 = pd.read_excel(file1_path)
df2 = pd.read_excel(file2_path)

# Concatenate the dataframes
combined_df = pd.concat([df1, df2], ignore_index=True)

# Display the combined dataframe
combined_df
# Out:
#    BANC_CODIGO_BANCO  COD_ADUANA_PRESENTADA  ADUANA_PRESENTADA  \
# 0                 19                      3  Aduanas de Bogota
# 1                 19                      3  Aduanas de Bogota
# 2                 91                      3  Aduanas de Bogota
# 3                 91                      3  Aduanas de Bogota
# 4                  7                      3  Aduanas de Bogota
# 5                 13                      3  Aduanas de Bogota
# 6                 13                      3  Aduanas de Bogota
# 7                 13                      3  Aduanas de Bogota
#
#    CODIGO_SUCURSAL  CODIGO_CAJERO  CONSECUTIVO_CAJERO  \
# 0               71              3                 264
# 1               71              3                 266
# 2                3              3              501488
# 3                3              3              501473
# 4              237             26              475985
# 5              346              2               13666
# ...

# %%
# prompt: SELECCIONE LA COLUMNA PAIS_COMPRA

select_pais = combined_df['PAIS_COMPRA']
select_pais.head(10)
# Out:
# 0                        CHINA
# 1                        CHINA
# 2                       BRASIL
# 3                       BRASIL
# 4    ESTADOS UNIDOS DE AMÉRICA
# 5                       ITALIA
# 6                       ITALIA
# 7                       ITALIA
# Name: PAIS_COMPRA, dtype: object

# %%
combined_df.to_csv('importaciones_comb.csv', index=False)

# %%
#merge productos
# File paths
file3_path = r"/content/2019.xlsx"
file4_path = r"/content/2021.xlsx"

# Read the Excel files
df3 = pd.read_excel(file3_path)
df4 = pd.read_excel(file4_path)

# Concatenate the dataframes
comb_df = pd.concat([df3, df4], ignore_index=True)

# Display the combined dataframe
comb_df
# Out:
#            Zona    Dpto  Id_ciudad        Ciudad  Unidades   Ventas_Pesos  \
# 0         NORTE   Cesar      20001    VALLEDUPAR          1     1903697.0
# 1         NORTE   Cesar      20001    VALLEDUPAR          1     1059328.0
# 2         NORTE   Cesar      20001    VALLEDUPAR          1     2011849.0
# 3         NORTE   Cesar      20710   SAN ALBERTO          1      669328.0
# 4         NORTE   Cesar      20011     AGUACHICA          1      294118.0
# ...         ...     ...        ...           ...        ...           ...
# 776346  ORIENTE  ARAUCA      81794          TAME          1     2048739.0
# 776347  ORIENTE  ARAUCA      81001        ARAUCA          1     1313445.0
# 776348  ORIENTE  ARAUCA      23570  PUEBLO NUEVO          1     1313445.0
# 776349  ORIENTE  ARAUCA      81736      SARAVENA          1     3016807.0
# 776350  ORIENTE  ARAUCA      81794          TAME          1     2902521.0
#
#              Marca              Referencia         Linea   Categoria  \
# ...

# %%
comb_df.to_csv('product_comb.cvs', index=False)
